# %%
display(dbutils.fs.ls('/databricks-datasets/'))

# %%
dbutils.help()

# %%
dbutils.fs.help('cp')

# %%
ENV='dev'

# %%
def show_greeting():
    print('hello')

# %%
# %sql
select current_metastore();
