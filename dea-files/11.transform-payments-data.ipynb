-- %%
select *
from gizmobox.bronze.payments
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %% [markdown]
-- ## 1. extract date and time from timestamp column

-- %% [markdown]
-- https://learn.microsoft.com/en-us/azure/databricks/sql/language-manual/functions/date_format

-- %%
select 
payment_id,
order_id,
payment_timestamp,
cast(date_format(payment_timestamp, 'yyyy-MM-dd') as date) as payment_date,
date_format(payment_timestamp, 'HH:mm:ss') as payment_time,
payment_status,
payment_method
from gizmobox.bronze.payments
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %% [markdown]
-- ## 2. categorize payment_status to text strings

-- %%
select 
payment_id,
order_id,
payment_timestamp,
cast(date_format(payment_timestamp, 'yyyy-MM-dd') as date) as payment_date,
date_format(payment_timestamp, 'HH:mm:ss') as payment_time,
payment_status,
case payment_status
when 1 then 'Succeeded'
when 2 then 'Pending'
when 3 then 'Cancelled'
when 4 then 'Failed'
end as payment_status_values,
payment_method
from gizmobox.bronze.payments
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
create table if not exists gizmobox.silver.payments
as
select 
payment_id,
order_id,
payment_timestamp,
cast(date_format(payment_timestamp, 'yyyy-M-d') as date) as payment_date,
date_format(payment_timestamp, 'HH:mm:ss') as payment_time,
payment_status,
case payment_status
when 1 then 'Succeeded'
when 2 then 'Pending'
when 3 then 'Cancelled'
when 4 then 'Failed'
end as payment_status_values,
payment_method
from gizmobox.bronze.payments
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

-- %%
select * from gizmobox.silver.payments
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...
