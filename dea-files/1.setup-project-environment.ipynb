-- %% [markdown]
-- https://learn.microsoft.com/en-us/azure/databricks/sql/language-manual/sql-ref-syntax-ddl-create-location

-- %%
CREATE EXTERNAL LOCATION IF NOT EXISTS sb1981_ext_dl_demo
    URL 'abfss://demo@sb1981ws7sa.dfs.core.windows.net'
    WITH (STORAGE CREDENTIAL `sb1981ws7stcred`)
    COMMENT 'create external location - demo'

-- %%
%fs ls 'abfss://demo@sb1981ws7sa.dfs.core.windows.net'

-- %%
%fs ls 'abfss://gizmobox@sb1981db4sa1.dfs.core.windows.net/landing/operational_data/'

-- %% [markdown]
-- ## Create external location

-- %%
drop external location if exists sb1981_ext_dl_gizmobox

-- %%
CREATE EXTERNAL LOCATION IF NOT EXISTS sb1981_ext_dl_gizmobox
    URL 'abfss://gizmobox@sb1981db4sa1.dfs.core.windows.net'
    WITH (STORAGE CREDENTIAL `sb1981-db4-ws1-ac1-cred1`)
    COMMENT 'create external location - gizmobox'

-- %%
drop catalog if exists gizmobox cascade

-- %% [markdown]
-- ## Create catalog
-- ### (prerequisite external location)

-- %%
show catalogs

-- %%
CREATE CATALOG IF NOT EXISTS gizmobox
      MANAGED LOCATION 'abfss://gizmobox@sb1981db4sa1.dfs.core.windows.net'
      COMMENT 'create gizmobox catalog';

-- %%
select current_catalog();

-- %%
use catalog gizmobox;

-- %% [markdown]
-- ## Create schema
-- ### (prerequisite external location)

-- %%
show schemas;

-- %%
use catalog gizmobox;

CREATE SCHEMA IF NOT EXISTS landing
  MANAGED LOCATION 'abfss://gizmobox@sb1981db4sa1.dfs.core.windows.net/landing'
  COMMENT 'create landing schema';

CREATE SCHEMA IF NOT EXISTS bronze
  MANAGED LOCATION 'abfss://gizmobox@sb1981db4sa1.dfs.core.windows.net/bronze'
  COMMENT 'create bronze schema';
  CREATE SCHEMA IF NOT EXISTS silver
  MANAGED LOCATION 'abfss://gizmobox@sb1981db4sa1.dfs.core.windows.net/silver'
  COMMENT 'create silver schema';
  CREATE SCHEMA IF NOT EXISTS gold
  MANAGED LOCATION 'abfss://gizmobox@sb1981db4sa1.dfs.core.windows.net/gold'
  COMMENT 'create gold schema';

-- %% [markdown]
-- ## Create Volume
-- ### (prerequisite external location)

-- %%
%fs ls 'abfss://gizmobox@sb1981db4sa1.dfs.core.windows.net/landing/operational_data/'

-- %%
CREATE EXTERNAL LOCATION IF NOT EXISTS sb1981_extloc_dl_gizmobox
    URL 'abfss://gizmobox@sb1981db4sa1.dfs.core.windows.net'
    WITH (STORAGE CREDENTIAL `sb1981-db4-ws1-ac1-cred1`)
    COMMENT 'create external location'

-- %%
use catalog gizmobox;
use schema landing;
CREATE EXTERNAL VOLUME IF NOT EXISTS operational_data
    LOCATION 'abfss://gizmobox@sb1981db4sa1.dfs.core.windows.net/landing/operational_data';

-- %%
%fs ls '/Volumes/gizmobox/landing/operational_data/addresses/'

-- %%
%fs ls '/Volumes/gizmobox/landing/operational_data/customers/'
