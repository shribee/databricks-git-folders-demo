# %%
print('hello')

# %%
# %run "/Workspace/Users/balansrikant@gmail.com/databricks-git-folders-demo/dea-files/3.utilities"

# %%
ENV

# %%
print(ENV)

# %%
show_greeting()

# %%
# %fs
ls "dbfs:/databricks-datasets/"

# %%
# %sh ps

# %%
# %pip install fastapi
